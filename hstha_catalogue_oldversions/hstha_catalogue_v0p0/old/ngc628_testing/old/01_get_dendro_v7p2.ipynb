# %%
import warnings
warnings.filterwarnings('ignore')

from analysis_phangs_hst import dendro_cutouts, dendro_dendro, dendro_misc, dendro_props, dendro_plot, dendro_mask

# %%
# Get Galaxy properties
galaxy = 'ngc0628'
# min_value_sig = [2, 3, 4, 5]
min_value_sig = [3]

sampletable = dendro_dendro.get_GalaxyProps(galaxy)
muscat_table = dendro_dendro.get_MuseProps(galaxy)

hdus = dendro_misc.load_pickle('../../analysis/catalogue/hdus_sample_sci.pickel')
# Out:
# [INFO] [get_GalaxyProps] Getting sample table properties for ngc0628...
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc0628...
# [INFO] [load_pickle] Load ../../analysis/catalogue/hdus_sample_sci.pickel

# %%
# Specify the regions file
# regions_file = './../../analysis/catalogue/sample_v2.reg'
regions_file = './../../analysis/catalogue/sample_muse.reg'

# Call the get_regions function to retrieve the region properties with a progress bar
regions = dendro_cutouts.get_regions(regions_file)

# Call the process_regions function and store the returned values
hdus, muscat_ids = dendro_dendro.get_maskedhdus(hdus, regions)
# Out:
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 2369 regions...
# [INFO] [get_maskedhdus] Getting HST maps masked by MUSE catalouge...
# Masking regions:   0%|          | 0/2369 [00:00<?, ?it/s]

# %%
# Using the `get_dedro_all_decorator` function from the `dendro_dendro` module,
# process the given HDUs to extract dendrogram properties based on the minimum
# value significance (`min_value_sig`), the sample table (`sampletable`), 
# and the MUSCAT IDs (`muscat_ids`). This will return the processed HDUs and the
# extracted dendrogram properties for each HDU.
hdus, props_all = dendro_dendro.get_dedro_all_decorator(hdus, min_value_sig, sampletable, muscat_ids)

# Augment the extracted dendrogram properties (`props_all`) with additional 
# information from the MUSCAT table (`muscat_table`) using the `add_muse_info`
# function from the `dendro_dendro` module.
props_all = dendro_dendro.add_muse_info(props_all, muscat_table)

for key in props_all.keys():
    props_all[key]['flux_corr'] = dendro_props.correct_ha_flux(props_all[key]['flux'], props_all[key])
    props_all[key]['ha_lum_hst'] = dendro_props.calculate_luminosity(props_all[key]['flux_corr']*1e-20, props_all[key]['dist_pc'])
    
dendro_misc.save_pickle(hdus, '../../analysis/catalogue/hdus_sample_withdendro.pickel')
dendro_misc.save_pickle(props_all, '../../analysis/dendro/props_all/01_props_all_allsig.pickel')        
dendro_dendro.save_fits(props_all)
# Out:
# Dendrogram (with sigma ranges):   0%|          | 0/2369 [00:00<?, ?it/s]
# [INFO] [get_dedro] [regionID=0] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=0] [min_value_sig=3] Initialising props_all table...
# [INFO] [props_all] [regionID=0] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=1] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=1] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=7] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=7] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=10] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=10] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=11] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=11] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=15] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=15] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=16] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=16] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=17] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=17] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=18] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=18] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=19] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=19] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=22] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=22] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=24] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=24] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=28] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=28] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=29] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=29] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=35] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=35] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=40] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=40] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=42] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=42] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=45] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=45] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=46] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=46] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=53] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=53] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=57] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=57] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=59] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=59] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=67] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=67] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=75] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=75] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=76] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=76] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=77] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=77] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=89] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=89] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=93] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=93] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=94] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=94] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=95] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=95] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=99] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=99] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=100] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=100] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=102] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=102] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=103] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=103] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=105] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=105] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=107] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=107] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=111] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=111] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=114] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=114] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=115] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=115] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=116] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=116] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=117] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=117] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=119] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=119] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=121] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=121] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID
[min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=595] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=595] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=596] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=596] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=597] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=597] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=599] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=599] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=600] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=600] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=602] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=602] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=604] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=604] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=606] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=606] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=607] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=607] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=609] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=609] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=610] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=610] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=611] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=611] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=612] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=612] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# ...
# [INFO] [props_all] [regionID=2269] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2270] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2270] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2271] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2271] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2272] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2272] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2273] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2273] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2274] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2274] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2275] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2275] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2276] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2276] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2278] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2278] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2279] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2279] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2280] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2280] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2281] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2281] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2282] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2282] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2283] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2283] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2284] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2284] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2285] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2285] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2288] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2288] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2289] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2289] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2290] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2290] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2291] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2291] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2292] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2292] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2293] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2293] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2294] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2294] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2295] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2295] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2296] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2296] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2297] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2297] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2298] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2298] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2299] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2299] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2300] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2300] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2301] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2301] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2302] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2302] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2303] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2303] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2304] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2304] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2305] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2305] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2306] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2306] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2309] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2309] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2310] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2310] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2311] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2311] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2312] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2312] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2313] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2313] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2315] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2315] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2316] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2316] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2317] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2317] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2318] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2318] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2319] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2319] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2320] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2320] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2321] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2321] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2322] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2322] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2323] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2323] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2324] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2324] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2325] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2325] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2326] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2326] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2327] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2327] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2328] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2328] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2329] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2329] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2330] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2330] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2331] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2331] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2332] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2332] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2333] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2333] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2334] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2334] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2335] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2335] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2337] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2337] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2338] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2338] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2339] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2339] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2340] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2340] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2341] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2341] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2342] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2342] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2344] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2344] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2345] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2345] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2346] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2346] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2348] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2348] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2350] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2350] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2351] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2351] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2352] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2352] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2353] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2353] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2354] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2354] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2355] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2355] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2356] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2356] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2357] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2357] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2361] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2361] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2362] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2362] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2363] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2363] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2366] [min_value_sig=3] No dendro found, all nan values...
# [INFO] [props_all] [regionID=2366] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [get_dedro] [regionID=2367] [min_value_sig=3] No dendro found...
# [INFO] [props_all] [regionID=2367] [min_value_sig=3] No sigma mask, all blank added to indexmap_trunk_hdu...
# [INFO] [add_muse_info] Adding MUSE catalouge info to final table...
# [INFO] [save_pickle] Saved to ../../analysis/catalogue/hdus_sample_withdendro.pickel
# [INFO] [save_pickle] Saved to ../../analysis/dendro/props_all/01_props_all_allsig.pickel
# [INFO] [save_fits] Saved to ../../analysis/dendro/props_all/01_props_all_3sig.fits

# %%
from importlib import reload
reload(dendro_mask)

dendro_mask.get_ds9regions_circ_decor(props_all['3sig'], outputfile='../../analysis/dendro/regions/%s_trunk_regions.reg' %galaxy)
dendro_mask.get_ds9regions_ellip_decor(props_all['3sig'], outputfile='../../analysis/dendro/regions/%s_sigma_regions.reg' %galaxy)

from astropy.io import fits
dir_hst = '../../../../ngc628c/data/hst_contsub/f658n_f555w_f814w/'
hst07_file = '%s/ngc628_halpha_bgsub_fit_anchored_intnegs_nocosmic_nnet.fits' %dir_hst
hdu = fits.open(hst07_file)[0]

dendro_mask.get_hdumask(hdus, hdu, outputfile='../../analysis/dendro/regions/%s_trunk_mask.fits' %galaxy)
# Out:
# Masking regions:   0%|          | 0/2369 [00:00<?, ?it/s]

# %%
# Using the `plot_sigmacomp_decorator` function from the `dendro_dendro_plot` module,
# plot a sigma comparison based on the provided HDUs, dendrogram properties (`props_all`), 
# regions, region ID (`regionID`), and minimum value significance (`min_value_sig`).

# dendro_dendro_plot.plot_sigmacomp_decorator(hdus, props_all, regions, min_value_sig)
