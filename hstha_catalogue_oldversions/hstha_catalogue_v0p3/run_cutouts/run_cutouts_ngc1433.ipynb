# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc1433'
galaxy_hst = galaxy
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1433/hst_contsub/ngc1433_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1433/muse/NGC1433_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1433/muse/NGC1433-0.91asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc1433...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 1736 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/1736 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 4
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 12
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 26
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 32
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 63
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 88
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 93
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 106
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 107
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 110
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 112
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 121
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 133
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 146
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 162
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 169
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 170
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 185
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 187
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 191
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 195
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 200
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 215
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 232
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 237
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 251
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 257
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 258
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 266
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 283
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 295
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 303
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 313
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 319
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 340
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 353
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 372
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 374
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 378
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 387
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 392
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 425
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 429
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 434
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 443
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 448
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 455
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 467
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 485
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 495
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 517
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 530
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 531
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 535
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 544
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 545
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 558
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 561
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 577
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 612
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 622
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 626
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 627
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 643
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 644
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 655
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 661
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 663
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 673
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 688
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 705
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 709
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 718
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 728
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 736
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 749
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 757
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 759
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 781
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 787
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 794
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 802
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 814
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 825
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 840
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 856
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 858
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 869
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 877
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 891
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 898
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 900
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 906
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 908
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 925
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 936
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 953
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 956
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 964
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1022
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1030
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1032
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1038
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1055
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1075
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1093
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1096
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1106
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1140
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1142
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1156
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1171
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1175
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1191
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1211
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1218
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1271
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1282
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1287
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1291
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1302
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1307
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1316
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1319
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1349
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1355
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1356
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1389
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1413
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1442
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1463
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1473
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1484
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1506
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1552
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1572
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1606
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1623
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1654
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1661
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1664
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1665
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1671
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1674
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1681
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1724
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1727
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1734
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1735
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/hstha_hdu.pickel
# [INFO] Running for musha_hdu...
# Cropping regions:   0%|          | 0/1736 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/musha_hdu.pickel
# [INFO] Running for muscat_hdu...
# Cropping regions:   0%|          | 0/1736 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/muscat_hdu.pickel

# %%
# Load all cutouts and save in one file... 

names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']
hdus_cutouts = {}

for name in tqdm(names):

    hdu_cutouts = dendro_misc.load_pickle('%s/%s.pickel' %(cutout_dir, name))
    hdus_cutouts[name] = hdu_cutouts

dendro_misc.save_pickle(hdus_cutouts, '%s/hdus_all.pickel' %cutout_dir)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/hstha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/musha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/muscat_hdu.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1433/cutouts/hdus_all.pickel
