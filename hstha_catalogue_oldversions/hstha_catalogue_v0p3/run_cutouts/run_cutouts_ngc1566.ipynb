# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc1566'
galaxy_hst = galaxy
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1566/hst_contsub/ngc1566_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1566/muse/NGC1566_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1566/muse/NGC1566-0.80asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc1566...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 2404 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/2404 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 0
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 39
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 63
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 75
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 113
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 125
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 126
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 147
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 151
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 171
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 172
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 176
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 191
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 193
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 211
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 212
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 251
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 254
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 280
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 311
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 344
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 347
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 429
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 457
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 493
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 534
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 576
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 580
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 646
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 685
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 736
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 754
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 759
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 768
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 776
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 792
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 853
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 860
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 865
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 890
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 908
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 915
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 987
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1007
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1021
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1030
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1045
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1048
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1070
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1085
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1113
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1119
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1148
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1160
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1189
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1191
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1211
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1212
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1299
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1320
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1394
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1411
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1484
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1492
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1497
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1531
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1535
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1539
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1547
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1566
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1579
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1713
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1745
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1775
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1807
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1858
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1983
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1999
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2051
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2130
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2199
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2219
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2347
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 2357
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/hstha_hdu.pickel
# [INFO] Running for musha_hdu...
# Cropping regions:   0%|          | 0/2404 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/musha_hdu.pickel
# [INFO] Running for muscat_hdu...
# Cropping regions:   0%|          | 0/2404 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/muscat_hdu.pickel

# %%
# Load all cutouts and save in one file... 

names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']
hdus_cutouts = {}

for name in tqdm(names):

    hdu_cutouts = dendro_misc.load_pickle('%s/%s.pickel' %(cutout_dir, name))
    hdus_cutouts[name] = hdu_cutouts

dendro_misc.save_pickle(hdus_cutouts, '%s/hdus_all.pickel' %cutout_dir)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/hstha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/musha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/muscat_hdu.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1566/cutouts/hdus_all.pickel
