# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc4321'
galaxy_hst = galaxy
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc4321/hst_contsub/ngc4321_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc4321/muse/NGC4321_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc4321/muse/NGC4321-1.16asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc4321...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 1847 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/1847 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 13
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 17
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 21
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 22
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 27
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 28
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 31
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 33
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 37
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 42
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 45
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 49
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 51
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 68
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 78
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 86
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 117
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 125
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 140
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 158
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 167
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 170
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 206
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 209
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 213
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 220
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 221
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 222
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 240
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 251
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 255
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 282
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 292
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 296
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 301
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 308
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 315
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 319
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 322
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 333
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 341
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 349
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 368
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 373
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 385
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 391
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 396
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 398
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 404
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 407
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 416
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 434
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 440
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 454
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 456
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 457
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 464
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 478
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 496
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 505
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 534
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 557
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 558
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 559
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 564
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 578
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 580
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 613
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 617
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 633
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 634
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 637
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 662
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 682
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 685
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 693
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 696
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 702
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 721
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 723
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 724
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 726
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 728
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 731
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 749
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 756
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 788
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 796
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 812
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 816
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 818
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 827
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 829
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 834
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 843
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 848
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 856
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 858
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 864
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 868
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 871
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 878
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 880
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 882
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 886
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 897
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 898
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 906
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 908
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 916
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 926
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 946
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 949
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 972
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 987
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 988
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 992
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1001
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1002
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1010
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1017
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1032
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1053
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1064
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1088
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1095
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1126
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1140
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1141
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1157
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1162
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1168
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1171
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1174
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1178
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1183
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1204
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1217
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1233
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1241
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1243
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1257
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1269
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1273
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1277
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1291
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1299
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1316
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1319
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1331
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1339
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1340
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1341
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1354
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1356
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1361
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1363
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1375
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1385
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1386
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1389
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1395
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1400
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1408
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1410
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1411
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1416
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1424
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1432
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1433
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1439
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1445
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1448
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1459
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1468
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1494
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1501
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1513
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1516
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1521
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1522
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1543
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1548
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1558
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1566
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1567
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1592
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1593
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1604
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1608
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1625
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1630
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1635
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1642
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1646
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1655
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1658
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1682
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1685
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1696
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1705
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1708
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1718
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1750
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1756
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1773
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1785
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1792
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1812
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1813
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1829
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1832
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1835
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1838
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/hstha_hdu.pickel
# [INFO] Running for musha_hdu...
# Cropping regions:   0%|          | 0/1847 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/musha_hdu.pickel
# [INFO] Running for muscat_hdu...
# Cropping regions:   0%|          | 0/1847 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/muscat_hdu.pickel

# %%
# Load all cutouts and save in one file... 

names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']
hdus_cutouts = {}

for name in tqdm(names):

    hdu_cutouts = dendro_misc.load_pickle('%s/%s.pickel' %(cutout_dir, name))
    hdus_cutouts[name] = hdu_cutouts

dendro_misc.save_pickle(hdus_cutouts, '%s/hdus_all.pickel' %cutout_dir)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/hstha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/musha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/muscat_hdu.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc4321/cutouts/hdus_all.pickel
