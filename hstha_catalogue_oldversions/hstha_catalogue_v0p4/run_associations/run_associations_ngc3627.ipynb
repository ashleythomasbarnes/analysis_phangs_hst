# %%
from imports import *

# %%
# Define names and filenames...

galaxy = 'ngc3627'
galaxy_cat = galaxy
galaxy_hst = galaxy
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

# Define names and filenames...
hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name
cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/catalogue' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)
regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir
catalog_mask_file = '%s/%s_mask.fits' %(dendro_dir, galaxy)

for prints in [hstha_file, muscat_file, musha_file, regions_file, regions_pickel_file, 
               sample_table_file, muscat_table_file, catalog_mask_file]:
    
    if os.path.isfile(prints):
        print('File found: %s' %prints)
    else: 
        print('File not found: %s' %prints)

# Define the association data... 
association_table_file_v_08pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws8pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws8pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_v_16pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws16pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws16pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_v_32pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws32pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws32pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_v_64pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws64pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws64pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)

association_table_file_nuv_08pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws8pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_nuv_16pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws16pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_nuv_32pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws32pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_table_file_nuv_64pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws64pc-main.fits' %(root_dir, galaxy_cat, galaxy_cat)

association_mask_file_v_08pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws8pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws8pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_v_16pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws16pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws16pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_v_32pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws32pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws32pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_v_64pc = '%s/data_misc/multiscale_stellar_associations/%s/vselect/ws64pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-vselect-ws64pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)

association_mask_file_nuv_08pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws8pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_nuv_16pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws16pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_nuv_32pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws32pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)
association_mask_file_nuv_64pc = '%s/data_misc/multiscale_stellar_associations/%s/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_%s_v1p3_multi_assoc-nuvselect-ws64pc-idmask.fits' %(root_dir, galaxy_cat, galaxy_cat)

# Upacks the association ID mask map for each galaxy - will remove at end (space saving...)
for file in [association_table_file_v_08pc, association_table_file_v_16pc, association_table_file_v_32pc, association_table_file_v_64pc,
                association_table_file_nuv_08pc, association_table_file_nuv_16pc, association_table_file_nuv_32pc, association_table_file_nuv_64pc,
                association_mask_file_v_08pc, association_mask_file_v_16pc, association_mask_file_v_32pc, association_mask_file_v_64pc,
                association_mask_file_nuv_08pc, association_mask_file_nuv_16pc, association_mask_file_nuv_32pc, association_mask_file_nuv_64pc]:
    
    cat_misc.get_unpack(file)

for file in [association_table_file_v_08pc, association_table_file_v_16pc, association_table_file_v_32pc, association_table_file_v_64pc,
                association_table_file_nuv_08pc, association_table_file_nuv_16pc, association_table_file_nuv_32pc, association_table_file_nuv_64pc,
                association_mask_file_v_08pc, association_mask_file_v_16pc, association_mask_file_v_32pc, association_mask_file_v_64pc,
                association_mask_file_nuv_08pc, association_mask_file_nuv_16pc, association_mask_file_nuv_32pc, association_mask_file_nuv_64pc]:
    
    if os.path.isfile(file):
        print('File found: %s' %file)
    else: 
        print('File not found: %s' %file)

# Read in the data...
props_associations_v_08pc = QTable.read(association_table_file_v_08pc)
props_associations_v_16pc = QTable.read(association_table_file_v_16pc)
props_associations_v_32pc = QTable.read(association_table_file_v_32pc)
props_associations_v_64pc = QTable.read(association_table_file_v_64pc)

props_associations_nuv_08pc = QTable.read(association_table_file_nuv_08pc)
props_associations_nuv_16pc = QTable.read(association_table_file_nuv_16pc)
props_associations_nuv_32pc = QTable.read(association_table_file_nuv_32pc)
props_associations_nuv_64pc = QTable.read(association_table_file_nuv_64pc)

hdu_association_mask_v_08pc = fits.open(association_mask_file_v_08pc)[0]
hdu_association_mask_v_16pc = fits.open(association_mask_file_v_16pc)[0]
hdu_association_mask_v_32pc = fits.open(association_mask_file_v_32pc)[0]
hdu_association_mask_v_64pc = fits.open(association_mask_file_v_64pc)[0]

hdu_association_mask_nuv_08pc = fits.open(association_mask_file_nuv_08pc)[0]
hdu_association_mask_nuv_16pc = fits.open(association_mask_file_nuv_16pc)[0]
hdu_association_mask_nuv_32pc = fits.open(association_mask_file_nuv_32pc)[0]
hdu_association_mask_nuv_64pc = fits.open(association_mask_file_nuv_64pc)[0]
# Out:
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/hst_contsub/ngc3627_hst_ha.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/muse/NGC3627_nebmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/muse/NGC3627-1.05asec_MAPS.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.reg
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.pickel
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/catalogue/ngc3627_mask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws8pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws16pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws32pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws64pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws8pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws16pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws32pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws64pc-main.fits
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws8pc-idmask.fits.gz
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws16pc-idmask.fits.gz
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws32pc-idmask.fits
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws64pc-idmask.fits.gz
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws8pc-idmask.fits.gz
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws16pc-idmask.fits.gz
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws32pc-idmask.fits.gz
# Unpacking: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws64pc-idmask.fits.gz
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws8pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws16pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws32pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws64pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws8pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws16pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws32pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws64pc-main.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws8pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws16pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws32pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws64pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws8pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws16pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws32pc-idmask.fits
# File found: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws64pc-idmask.fits

# %%
# Load regions, sample table and HDUs... 
hdus_cutouts  = cat_misc.load_pickle('%s/hdus_all.pickel' %cutout_dir)
regions       = cat_misc.load_pickle(regions_pickel_file)
props_all     = QTable.read('%s/props_all.fits' %dendro_dir)
hdu_catalog_mask = fits.open(catalog_mask_file)[0] # Neb catalogue mask

# Get only regions in the props table...
region_IDs = props_all['region_ID']
for key in regions.keys():
    regions[key] = regions[key][region_IDs.astype(int).tolist()]
# Out:
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_all.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.pickel

# %%
# Get cutouts... 
rerun_cutouts = True
if rerun_cutouts:

    # Get cutouts of the association mask
    hdus_association_mask_new_v_08pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_v_08pc, regions) 
    hdus_association_mask_new_v_16pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_v_16pc, regions)
    hdus_association_mask_new_v_32pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_v_32pc, regions)
    hdus_association_mask_new_v_64pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_v_64pc, regions)

    hdus_association_mask_new_nuv_08pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_nuv_08pc, regions)
    hdus_association_mask_new_nuv_16pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_nuv_16pc, regions)
    hdus_association_mask_new_nuv_32pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_nuv_32pc, regions)
    hdus_association_mask_new_nuv_64pc = cat_cutouts.get_croppeddata_all(hdu_association_mask_nuv_64pc, regions)
    
    # Get cutouts of the neb catalog mask
    hdus_catalog_mask_new = cat_cutouts.get_croppeddata_all(hdu_catalog_mask, regions) 

    # Save cutouts...
    cat_misc.save_pickle(hdus_association_mask_new_v_08pc, '%s/hdus_association_mask_new_v_08pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_v_16pc, '%s/hdus_association_mask_new_v_16pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_v_32pc, '%s/hdus_association_mask_new_v_32pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_v_64pc, '%s/hdus_association_mask_new_v_64pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_nuv_08pc, '%s/hdus_association_mask_new_nuv_08pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_nuv_16pc, '%s/hdus_association_mask_new_nuv_16pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_nuv_32pc, '%s/hdus_association_mask_new_nuv_32pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_association_mask_new_nuv_64pc, '%s/hdus_association_mask_new_nuv_64pc.pickel' %cutout_dir)
    cat_misc.save_pickle(hdus_catalog_mask_new, '%s/hdus_catalog_mask_new.pickel' %cutout_dir)

else:

    # Load cutouts if already run...
    hdus_association_mask_new_v_08pc = cat_misc.load_pickle('%s/hdus_association_mask_new_v_08pc.pickel' %cutout_dir)
    hdus_association_mask_new_v_16pc = cat_misc.load_pickle('%s/hdus_association_mask_new_v_16pc.pickel' %cutout_dir)
    hdus_association_mask_new_v_32pc = cat_misc.load_pickle('%s/hdus_association_mask_new_v_32pc.pickel' %cutout_dir)
    hdus_association_mask_new_v_64pc = cat_misc.load_pickle('%s/hdus_association_mask_new_v_64pc.pickel' %cutout_dir)

    hdus_association_mask_new_nuv_08pc = cat_misc.load_pickle('%s/hdus_association_mask_new_nuv_08pc.pickel' %cutout_dir)
    hdus_association_mask_new_nuv_16pc = cat_misc.load_pickle('%s/hdus_association_mask_new_nuv_16pc.pickel' %cutout_dir)
    hdus_association_mask_new_nuv_32pc = cat_misc.load_pickle('%s/hdus_association_mask_new_nuv_32pc.pickel' %cutout_dir)
    hdus_association_mask_new_nuv_64pc = cat_misc.load_pickle('%s/hdus_association_mask_new_nuv_64pc.pickel' %cutout_dir)

    hdus_catalog_mask_new = cat_misc.load_pickle('%s/hdus_catalog_mask_new.pickel' %cutout_dir)
# Out:
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:20<00:00,  5.93it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:26<00:00,  5.53it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:29<00:00,  5.32it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:32<00:00,  5.13it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:35<00:00,  4.97it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:36<00:00,  4.95it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:32<00:00,  5.14it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:40<00:00,  4.75it/s]
# Cropping regions: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:57<00:00,  4.05it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_v_08pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_v_16pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_v_32pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_v_64pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_nuv_08pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_nuv_16pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_nuv_32pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_association_mask_new_nuv_64pc.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/hdus_catalog_mask_new.pickel

# %%
region_ID_all = np.unique(hdu_catalog_mask.data)
props_associations_all = []

for i in tqdm(range(len(props_all['region_ID']))):

    region_ID = props_all['region_ID'][i]

    # Get association IDs by masking the association mask with the region ID mask...
    association_IDs_v_08pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_v_08pc)
    association_IDs_v_16pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_v_16pc)
    association_IDs_v_32pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_v_32pc)
    association_IDs_v_64pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_v_64pc)

    association_IDs_nuv_08pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_nuv_08pc)
    association_IDs_nuv_16pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_nuv_16pc)
    association_IDs_nuv_32pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_nuv_32pc)
    association_IDs_nuv_64pc = cat_associations.get_association_IDs(region_ID, i, hdus_catalog_mask_new, hdus_association_mask_new_nuv_64pc)

    # Get the association properties...
    props_associations_new_v_08pc = cat_associations.get_all_associations(region_ID, association_IDs_v_08pc, props_associations_v_08pc, 'v_08pc')
    props_associations_new_v_16pc = cat_associations.get_all_associations(region_ID, association_IDs_v_16pc, props_associations_v_16pc, 'v_16pc')
    props_associations_new_v_32pc = cat_associations.get_all_associations(region_ID, association_IDs_v_32pc, props_associations_v_32pc, 'v_32pc')
    props_associations_new_v_64pc = cat_associations.get_all_associations(region_ID, association_IDs_v_64pc, props_associations_v_64pc, 'v_64pc')

    props_associations_new_nuv_08pc = cat_associations.get_all_associations(region_ID, association_IDs_nuv_08pc, props_associations_nuv_08pc, 'nuv_08pc')
    props_associations_new_nuv_16pc = cat_associations.get_all_associations(region_ID, association_IDs_nuv_16pc, props_associations_nuv_16pc, 'nuv_16pc')
    props_associations_new_nuv_32pc = cat_associations.get_all_associations(region_ID, association_IDs_nuv_32pc, props_associations_nuv_32pc, 'nuv_32pc')
    props_associations_new_nuv_64pc = cat_associations.get_all_associations(region_ID, association_IDs_nuv_64pc, props_associations_nuv_64pc, 'nuv_64pc')

    # Join the tables together using region_ID - one row per region_ID...
    props_associations_all_ = join(props_associations_new_v_08pc, props_associations_new_v_16pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_v_32pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_v_64pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_nuv_08pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_nuv_16pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_nuv_32pc, keys='region_ID')
    props_associations_all_ = join(props_associations_all_, props_associations_new_nuv_64pc, keys='region_ID')
    props_associations_all += [props_associations_all_]
# Out:
#  23%|████████████████████████████████████████████████                                                                                                                                                              | 111/476 [00:15<00:53,  6.79it/s]
# [INFO] Padding added to catalog mask to match association mask shape...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [01:07<00:00,  7.02it/s]

# %%
props_associations_stacked = vstack(props_associations_all) # Stack all the regions together...
props_all_association = join(props_all, props_associations_stacked, keys='region_ID') # Join the nebula table with the association table...

# Only take non-masked values in table
props_all_association.write('%s/props_all_association.fits' %dendro_dir, overwrite=True)
props_all_association
# Out:
# <QTable length=476>
# region_ID  x_max   y_max        x_com              y_com        ... age_ave_association_nuv_64pc mass_sum_association_nuv_64pc no_associations_association_nuv_64pc one_associations_association_nuv_64pc multiple_associations_association_nuv_64pc
#             pix     pix          pix                pix         ...
#  float64  float64 float64      float64            float64       ...           float64                       float64                            bool                                  bool                                    bool
# --------- ------- ------- ------------------ ------------------ ... ---------------------------- ----------------------------- ------------------------------------ ------------------------------------- ------------------------------------------
#       1.0    32.0    39.0 31.998137293234205  38.79759460373946 ...                           --                            --                                 True                                 False                                      False
#       2.0    46.0    57.0 47.783083142029064  52.15712059438367 ...                          nan                           nan                                False                                  True                                      False
#       3.0    37.0    42.0  35.40383512314825 41.829017493869024 ...                           --                            --                                 True                                 False                                      False
#       8.0   106.0   105.0 101.89894186221193 108.06816519857259 ...            7.000000000000001             80177.01534408549                                False                                 False                                       True
#      12.0    53.0    66.0  58.75847570399358   66.1872075536519 ...                           --                            --                                 True                                 False                                      False
#      13.0   105.0   101.0 102.73582366144502 108.08157374129848 ...                          nan                           nan                                False                                  True                                      False
#      14.0    56.0    72.0 59.449987715082685  67.88083895684876 ...                          nan                           nan                                False                                  True                                      False
#      17.0    51.0    54.0 50.076199681268726 57.734128353274706 ...                          nan                           nan                                False                                  True                                      False
#      21.0    65.0    65.0  65.64207927481168  67.72402286102013 ...                           --                            --                                 True                                 False                                      False
#      23.0    57.0    58.0  57.93888189345063  61.66313490513266 ...                          nan                           nan                                False                                  True                                      False
#      24.0    80.0    78.0  76.75833653239044  84.04359187794705 ...                           --                            --                                 True                                 False                                      False
#      28.0    41.0    52.0 41.017649038105354 48.480845309376754 ...                           --                            --                                 True                                 False                                      False
#      30.0    29.0    40.0 29.704483772281765  39.55997381000587 ...                          nan                           nan                                False                                  True                                      False
#      32.0    51.0    47.0 52.252718534358685  58.90468122552233 ...                           --                            --                                 True                                 False                                      False
#      33.0    41.0    51.0  44.18347272039941  47.31982568925624 ...                          nan                           nan                                False                                  True                                      False
#      34.0    35.0    52.0 36.602861539600006 51.452940645461226 ...                          nan                           nan                                False                                  True                                      False
#      37.0    64.0    76.0  63.85913032643444  75.19821696956427 ...                           --                            --                                 True                                 False                                      False
#      38.0    67.0    74.0  65.54021142755518  72.48940893240909 ...                          nan                           nan                                False                                  True                                      False
#      40.0    39.0    44.0  35.05374056606541  42.18107891241896 ...                           --                            --                                 True                                 False                                      False
#      42.0   123.0   115.0 122.08044298008382   126.890947808348 ...                        416.5             92593029.70753925                                False                                 False                                       True
#      44.0    52.0    60.0  53.16378196065752  61.89866627300549 ...                           --                            --                                 True                                 False                                      False
#      45.0    62.0    75.0   65.7090500402606  75.56426126218221 ...                          nan                           nan                                False                                  True                                      False
#      46.0    39.0    40.0   37.8232709548646 41.392771365155916 ...                          nan                           nan                                False                                  True                                      False
#      48.0    53.0    56.0  55.72441566638821  60.39020849121894 ...                          nan                           nan                                False                                  True                                      False
#      49.0    62.0    58.0   63.1925460928196  62.69061702263361 ...                          nan                           nan                                False                                  True                                      False
#      51.0   121.0   124.0 118.27179368929528  125.2503554345798 ...                          nan                           nan                                False                                  True                                      False
#      54.0    32.0    44.0  32.71188988601954  45.24656603133483 ...                           --                            --                                 True                                 False                                      False
#       ...     ...     ...                ...                ... ...                          ...                           ...                                  ...                                   ...                                        ...
#    1498.0    28.0    52.0  32.14149045028759  48.37222849804852 ...                           --                            --                                 True                                 False                                      False
#    1507.0    64.0    63.0  67.60389685648134  74.09361138701658 ...                           --                            --                                 True                                 False                                      False
#    1508.0    67.0    75.0  70.01901289818841  73.53324633133693 ...           14.666666666666666            1160250.7487097494                                False                                 False                                       True
#    1522.0    27.0    28.0 26.380209251032557 26.986132210916974 ...                           --                            --                                 True                                 False                                      False
#    1529.0    51.0    42.0  40.32987015457354  39.54807386006485 ...                          nan                           nan                                False                                  True                                      False
#    1530.0    62.0    60.0  57.64222199888546  69.22846008395038 ...                          nan                           nan                                False                                  True                                      False
#    1531.0    35.0    55.0  37.06349173834844 47.058481632399406 ...                           --                            --                                 True                                 False                                      False
#    1539.0    53.0    41.0  47.69118436849001  47.54080333903211 ...                           --                            --                                 True                                 False                                      False
#    1540.0    37.0    41.0  38.15147490339227  39.20371564735251 ...                           --                            --                                 True                                 False                                      False
#    1543.0    58.0    67.0 50.937229331983765  52.85061041122732 ...                          nan                           nan                                False                                  True                                      False
#    1547.0    75.0    70.0  71.77807417805077   79.1312299462163 ...                          4.0            1401360.0793593258                                False                                 False                                       True
#    1551.0    53.0    31.0  51.89076677850795  49.63591492672479 ...                           --                            --                                 True                                 False                                      False
#    1555.0    51.0    43.0 48.616578098844606  41.66133389244789 ...                          nan                           nan                                False                                  True                                      False
#    1556.0    50.0    49.0 48.281063716831895  44.24539071510267 ...                           --                            --                                 True                                 False                                      False
#    1568.0    23.0    23.0 28.825746813837895 21.871871298383564 ...                           --                            --                                 True                                 False                                      False
#    1569.0    83.0    93.0  89.27856943789598  92.81431394713763 ...                          nan                           nan                                False                                  True                                      False
#    1572.0    41.0    44.0 46.671533551321964 48.532022116164185 ...                           --                            --                                 True                                 False                                      False
#    1583.0    30.0    53.0  55.61164503802113  65.19544910679478 ...                          nan                           nan                                False                                  True                                      False
#    1585.0    38.0    31.0  38.26429898170321 30.648978133669427 ...                           --                            --                                 True                                 False                                      False
#    1593.0    46.0    25.0  43.88106264894095  45.23829666502688 ...                          nan                           nan                                False                                  True                                      False
#    1594.0    63.0    63.0 52.872674803700455  61.06616984607328 ...                           --                            --                                 True                                 False                                      False
#    1595.0    42.0    53.0  49.65620505625288  51.34762892556649 ...                           --                            --                                 True                                 False                                      False
#    1599.0    74.0    65.0  74.15767674486075  71.82402806151624 ...                          nan                           nan                                False                                  True                                      False
#    1619.0    26.0    42.0 23.625789092134674   39.6463030383664 ...                          nan                           nan                                False                                  True                                      False
#    1620.0    38.0    49.0  36.80342477350359  47.84846431834534 ...                           --                            --                                 True                                 False                                      False
#    1628.0    38.0    40.0   38.3451641787344  37.66138294088858 ...                          nan                           nan                                False                                  True                                      False
#    1629.0    42.0    54.0  41.92914394102932 54.091084261952105 ...                          nan                           nan                                False                                  True                                      False
#    1631.0    26.0    40.0 32.810712923578336  38.09820625599746 ...                          nan                           nan                                False                                  True                                      False

# %%
for file in [association_mask_file_v_08pc, association_mask_file_v_16pc, association_mask_file_v_32pc, association_mask_file_v_64pc,
            association_mask_file_nuv_08pc, association_mask_file_nuv_16pc, association_mask_file_nuv_32pc, association_mask_file_nuv_64pc]:

    cat_misc.clean_unpack(file)
# Out:
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws8pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws16pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws32pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/vselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-vselect-ws64pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws8pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws8pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws16pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws16pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws32pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws32pc-idmask.fits
# Cleaning: /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/multiscale_stellar_associations/ngc3627/nuvselect/ws64pc/PHANGS_IR4_hst_wfc3_ngc3627_v1p3_multi_assoc-nuvselect-ws64pc-idmask.fits
