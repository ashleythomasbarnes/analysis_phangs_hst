# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc3627'
galaxy_hst = galaxy
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/hst_contsub/ngc3627_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/muse/NGC3627_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc3627/muse/NGC3627-1.05asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc3627...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 1635 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc3627/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/1635 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 0
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 4
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 5
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 6
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 7
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 9
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 10
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 16
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 18
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 20
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 22
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 25
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 26
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 35
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 36
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 39
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 41
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 43
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 47
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 50
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 52
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 53
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 55
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 56
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 58
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 62
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 66
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 68
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 70
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 74
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 84
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 88
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 89
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 90
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 92
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 94
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 97
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 102
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 107
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 112
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 113
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 116
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 117
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 118
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 124
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 126
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 127
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 128
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 139
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 148
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 149
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 152
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 153
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 156
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 158
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 161
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 165
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 166
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 168
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 185
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 187
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 188
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 190
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 193
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 198
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 200
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 202
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 207
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 209
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 211
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 213
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 215
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 218
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 229
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 238
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 240
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 242
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 243
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 245
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 246
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 248
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 259
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 264
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 265
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 266
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 273
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 275
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 276
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 282
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 286
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 287
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 289
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 290
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 294
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 297
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 299
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 300
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 305
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region