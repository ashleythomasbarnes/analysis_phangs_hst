# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc0628'
galaxy_hst = 'ngc628e'
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628e/hst_contsub/ngc628e_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628e/muse/NGC0628_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628e/muse/NGC0628-0.92asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc0628...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 2869 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628e/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/2869 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 0
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 3
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 7
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 8
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 9
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 12
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 13
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 14
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 15
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 17
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 18
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 20
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 21
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 22
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 23
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 24
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 25
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 26
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 28
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 29
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 30
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 31
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 32
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 33
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 34
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 35
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 36
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 38
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 39
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 41
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 42
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 43
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 44
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 45
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 47
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 48
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 50
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 52
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 53
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 55
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 56
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 57
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 58
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 59
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 60
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 61
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 62
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 63
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 66
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 67
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 68
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 69
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 70
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 71
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 72
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 73
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 75
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 76
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 77
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 79
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 80
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 82
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 84
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 86
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 87
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 89
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 91
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 92
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 93
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 95
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 96
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 97
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 99
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 100
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 103
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 104
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 105
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 107
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 108
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 110
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 112
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 113
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 115
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 117
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 118
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 119
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 121
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 124
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region