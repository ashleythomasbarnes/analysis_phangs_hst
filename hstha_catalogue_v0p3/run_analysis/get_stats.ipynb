# %%
import numpy as np
from astropy import units as u 
from astropy.io import fits
import matplotlib.pyplot as plt
import matplotlib as mpl
from astropy.table import QTable

plt.style.use('paper.mplstyle')

# %%
import numpy as np

root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'
table = QTable.read('%s/data_hstha_nebulae_catalogue/all/nebulae_catalogue.fits' %root_dir)
table
# Out:
# <QTable length=11329>
# gal_name region_ID hstcat_region_ID ... region_circ_rad_pc flag_nearby_hst
#                                     ...         pc
# bytes32   float64       int64       ...      float64           float64
# -------- --------- ---------------- ... ------------------ ---------------
#   IC5332       0.0                0 ...  53.54209050712837             0.0
#   IC5332       1.0                1 ... 27.882345819039006             0.0
#   IC5332       3.0                3 ... 39.738456871229964             0.0
#   IC5332       4.0                4 ... 26.996965252583514             0.0
#   IC5332       5.0                5 ... 26.996965252583514             0.0
#   IC5332       6.0                6 ... 26.081546298598205             0.0
#   IC5332       7.0                7 ... 47.787933096066894             0.0
#   IC5332       8.0                8 ... 27.882345819039006             0.0
#   IC5332       9.0                9 ... 27.882345819039006             0.0
#      ...       ...              ... ...                ...             ...
#  NGC7496     747.0              747 ...  57.93090802750168             0.0
#  NGC7496     750.0              750 ...  58.82911520385716             0.0
#  NGC7496     752.0              752 ...  62.29256423346252             0.0
#  NGC7496     754.0              754 ...  77.99187178876193             0.0
#  NGC7496     759.0              759 ...  61.44500685981095             0.0
#  NGC7496     765.0              765 ...  62.29256423346252             1.0
#  NGC7496     770.0              770 ...  57.01855324465027             0.0
#  NGC7496     773.0              773 ... 59.713813196332865             0.0
#  NGC7496     774.0              774 ...  61.44500685981095             0.0
#  NGC7496     776.0              776 ...  61.44500685981095             0.0

# %%
# Calculate the percentiles for each "gal_name"
percentiles = [10, 50, 90]
columns = ['gal_name'] + [f'percentile_{p}' for p in percentiles]
data = []

for gal_name in np.unique(table['gal_name']):
    gal_data = [gal_name]
    for p in percentiles:
        percentile_value_ha = np.percentile(table[table['gal_name'] == gal_name]['HA6562_LUMINOSITY_HST'], p).to('dex(erg/s)')
        gal_data.extend([percentile_value_ha])
    # data.append(gal_data)
    for p in percentiles:
        percentile_value_rad = np.percentile(table[table['gal_name'] == gal_name]['radius_trunkclose_pc'], p)
        gal_data.extend([percentile_value_rad])
    data.append(gal_data)

# Create a new QTable with the calculated percentiles
new_columns = ['gal_name'] + [f'percentile_{p}_ha' for p in percentiles] + [f'percentile_{p}_rad' for p in percentiles]
new_table = QTable(rows=data, names=new_columns)

new_table
# Out:
# <QTable length=17>
# gal_name  percentile_10_ha  ... percentile_50_rad  percentile_90_rad
#             dex(erg / s)    ...         pc                 pc
#   str7        float64       ...      float64            float64
# -------- ------------------ ... ------------------ ------------------
#   IC5332  35.31241273795537 ...  5.735046453152933 23.495142186478255
#  NGC0628 35.465541721153116 ... 11.970006092487369 44.361589258247385
#  NGC1087  36.62238663154839 ...  23.48897545079117  83.66363451206917
#  NGC1300  36.11948660408052 ... 24.781235469500636  74.14404905785149
#  NGC1365  36.71271717124988 ... 23.947438694293773 133.60310220964345
#  NGC1385  36.73419889086912 ...  30.83389911075323 111.40789569124965
#  NGC1433 36.433037701511935 ... 15.040729974098387  51.59258175649266
#  NGC1566 36.700637512439386 ... 23.867541635308857  94.58289201704947
#  NGC1672  36.33042383639693 ...  40.65851534410595  119.3379252543163
#  NGC2835 36.239209916680444 ... 14.687157930342217  51.80351736325183
#  NGC3351  35.96629857638654 ...  8.835085062490998 30.942963641869113
#  NGC3627  36.47983038624868 ... 21.441454191227315  86.56475905593149
#  NGC4254  36.75672215160244 ...  35.09182114177013  87.73469095263063
#  NGC4303 36.756800594637554 ...   25.3461263777264   88.7055826783568
#  NGC4321 36.624474715669486 ...  18.79381229677988  69.82548912689597
#  NGC5068  35.27402083376538 ...  7.227694225556336 28.844109766717363
#  NGC7496 36.435641810380815 ... 20.886608345861834   90.9755588639038

# %%
names = ['gal_name',
         'percentile_10_ha',
         'percentile_50_ha',
         'percentile_90_ha',
         'percentile_10_rad',
         'percentile_50_rad',
         'percentile_90_rad']

formats={
        'gal_name': '%s',
        'percentile_10_ha': '%0.1f',
        'percentile_50_ha': '%0.1f',
        'percentile_90_ha': '%0.1f',
        'percentile_10_rad': '%0.1f',
        'percentile_50_rad': '%0.1f',
        'percentile_90_rad': '%0.1f'}

new_table.write('./tabs/lumrad_props.tex', formats=formats, names=names, overwrite=True)
