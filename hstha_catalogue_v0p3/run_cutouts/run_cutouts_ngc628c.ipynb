# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('./')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc0628'
galaxy_hst = 'ngc628c'
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628c/hst_contsub/ngc628c_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628c/muse/NGC0628_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc628c/muse/NGC0628-0.92asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc0628...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 2869 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc628c/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/2869 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 37
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 46
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 51
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 58
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 82
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 98
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 150
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 194
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 219
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 231
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 239
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 250
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 253
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 291
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 295
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 304
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 321
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 322
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 392
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 438
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 441
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 489
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 495
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/3y/cmsgt3_x7x72bbs__zhy_q6h0008wr/T/ipykernel_42483/4006804763.py in <module>
#       7
#       8     print('[INFO] Running for %s...' %name)
# ----> 9     hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
#      10     dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name))
#      11     del hdu_cutouts
#
# ~/GitHub/phangs/analysis_phangs_hst/hstha_catalogue_v0p1/modules/dendro_cutouts.py in get_croppeddata_all(hdu, regions)
#     141     hdus = []
#     142     for i in tqdm(range(n), desc="Cropping regions"):
# --> 143         hdus += [get_croppeddata(hdu, i, regions)]
#     144
#     145     return hdus
#
# ~/GitHub/phangs/analysis_phangs_hst/hstha_catalogue_v0p1/modules/dendro_cutouts.py in get_croppeddata(***failed resolving arguments***)
#     121     del hdu
#     122     del cutout  # Delete the cutout to free up memory
# --> 123     _ = gc.collect()  # Perform garbage collection
#     124
#     125     return hdu_crop  # Return the cropped HDU object
#
# KeyboardInterrupt:

# %%
# Load all cutouts and save in one file... 

names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']
hdus_cutouts = {}

for name in tqdm(names):

    hdu_cutouts = dendro_misc.load_pickle('%s/%s.pickel' %(cutout_dir, name))
    hdus_cutouts[name] = hdu_cutouts

dendro_misc.save_pickle(hdus_cutouts, '%s/hdus_all.pickel' %cutout_dir)
