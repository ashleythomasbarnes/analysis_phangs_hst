# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.io import fits
from tqdm.auto import tqdm 
import numpy as np
import os
import gc 
from glob import glob 
import sys
sys.path.append('../')
from modules import dendro_cutouts, dendro_misc

# %%
# Define names and filenames...

galaxy = 'ngc1365'
galaxy_hst = 'ngc1365n'
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies'

hstha_file = '%s/data_hstha/%s/hst_contsub/%s_hst_ha_sic.fits' %(root_dir, galaxy_hst, galaxy_hst)
muscat_file = '%s/data_hstha/%s/muse/%s_nebmask.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = '%s/data_hstha/%s/muse/%s-*_MAPS.fits' %(root_dir, galaxy_hst, galaxy.upper())
musha_file = glob(musha_file)[0] #because of resolution in name

cutout_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts' %(root_dir, galaxy_hst)
dendro_dir = '%s/data_hstha_nebulae_catalogue/%s/dendro' %(root_dir, galaxy_hst)
cutouts_hdus_dir = '%s/data_hstha_nebulae_catalogue/%s/cutouts_hdus' %(root_dir, galaxy_hst)

rerun_all = True
rerun_regions = True
rerun_masking = True

regions_file = '%s/sample.reg' %cutout_dir
regions_pickel_file = '%s/sample.pickel' %cutout_dir
sample_table_file = '%s/data_misc/sample_table/phangs_sample_table_v1p6.fits' %root_dir
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v3/Nebulae_catalogue_v3.fits' %root_dir

print(hstha_file)
print(muscat_file)
print(musha_file)
print(cutout_dir)
print(dendro_dir)
print(cutouts_hdus_dir)
print(regions_file)
print(regions_pickel_file)
print(sample_table_file)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1365n/hst_contsub/ngc1365n_hst_ha_sic.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1365n/muse/NGC1365_nebmask.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha/ngc1365n/muse/NGC1365-1.15asec_MAPS.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/dendro
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts_hdus
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/sample.reg
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/sample.pickel
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/sample_table/phangs_sample_table_v1p6.fits
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_misc/nebulae_catalogue/Nebulae_catalogue_v3.fits

# %%
# Make paths 

def make_paths(rootdir, galaxy_hst, rerun_all=False):

    root_dir = '%s/data_hstha_nebulae_catalogue/%s/' %(rootdir, galaxy_hst)
    cutout_dir = '%s/cutouts' %(root_dir)
    dendro_dir = '%s/dendro' %(root_dir)
    cutouts_hdus_dir = '%s/cutouts_hdus' %(root_dir)

    print('[Info] Outputing to the following:')
    print(root_dir)

    if rerun_all: 
        os.system('rm -rf '+root_dir)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir) 

    for path in [cutout_dir, dendro_dir, cutouts_hdus_dir]:

        if not os.path.isdir(path):
            os.mkdir(path)  

make_paths(root_dir, galaxy_hst)
# Out:
# [Info] Outputing to the following:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/

# %%
# Loading files...

hstha_hdu = fits.open(hstha_file)[0]
musha_hdu = fits.open(musha_file)['HA6562_FLUX']
muscat_hdu = fits.open(muscat_file)[0]

# Update arrays
musha_hdu.data[np.isnan(musha_hdu.data)] = -100
muscat_hdu.data = np.array(muscat_hdu.data, dtype=float)
muscat_hdu.data[muscat_hdu.data==-1] = np.nan

# Convert all hdus to float32
hdus = [hstha_hdu, musha_hdu, muscat_hdu]
hdus = [dendro_misc.convert_to_float32(hdu.copy()) for hdu in hdus]

# %%
# Get regions and sample table... 

if os.path.exists(regions_file) & ~rerun_regions:
    regions = dendro_misc.load_pickle(regions_pickel_file)
else: 
    muscat_table = dendro_misc.get_museprops(galaxy, muscat_table_file)
    regions_sky = dendro_cutouts.get_ds9regions_all(muscat_table, outputfile=regions_file)
    regions = dendro_cutouts.get_regions(regions_file)
    dendro_misc.save_pickle(regions, regions_pickel_file)
# Out:
# [INFO] [get_MuseProps] Getting MUSE catalouge properties for ngc1365...
# [INFO] [get_regions] Opening regions file (this may take a min)...
# [INFO] [get_regions] Getting info for 1455 regions...
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/sample.pickel

# %%
# Get cutouts and save... 

hdus = [hstha_hdu, musha_hdu, muscat_hdu]
names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']

for hdu, name in zip(hdus, names):

    print('[INFO] Running for %s...' %name)
    hdu_cutouts = dendro_cutouts.get_croppeddata_all(hdu, regions)
    dendro_misc.save_pickle(hdu_cutouts, '%s/%s.pickel' %(cutout_dir, name)) 
    del hdu_cutouts
    _ = gc.collect()
# Out:
# [INFO] Running for hstha_hdu...
# Cropping regions:   0%|          | 0/1455 [00:00<?, ?it/s]
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 3
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 11
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 14
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 17
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 20
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 24
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 26
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 34
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 47
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 50
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 61
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 67
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 76
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 81
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 101
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 102
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 114
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 116
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 118
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 119
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 120
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 125
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 132
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 152
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 154
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 160
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 161
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 162
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 164
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 174
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 175
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 176
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 179
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 180
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 182
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 186
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 188
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 189
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 209
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 210
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 214
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 222
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 238
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 243
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 250
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 251
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 252
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 253
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 258
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 273
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 281
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 282
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 290
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 301
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 303
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 306
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 312
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 325
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 328
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 337
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 339
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 341
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 345
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 363
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 365
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 369
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 376
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 396
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 397
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 404
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 408
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 409
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 410
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 423
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 427
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 431
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 433
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 437
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 440
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 449
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 456
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 459
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 463
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 472
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 488
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 496
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 502
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 503
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 510
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 518
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 521
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 528
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 537
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 538
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 540
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 541
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 544
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 549
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 555
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 560
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 567
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 573
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 578
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 588
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 593
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 601
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 619
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 631
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 634
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 650
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 654
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 658
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 659
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 672
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 677
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 684
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 686
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 704
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 717
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 719
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 721
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 723
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 726
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 740
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 742
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 753
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 765
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 772
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 779
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 780
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 785
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 789
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 791
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 799
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 802
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 803
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 824
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 825
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 830
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 835
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 838
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 849
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 866
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 870
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 883
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 884
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 886
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 888
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 891
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 892
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 893
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 895
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 913
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 915
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 922
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 940
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 949
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 950
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 954
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 973
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 993
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1003
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1006
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1024
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1037
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1044
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1050
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1060
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1061
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1078
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1103
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1108
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1110
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1143
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1151
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1153
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1155
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1158
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1167
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1173
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1176
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1177
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1212
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1218
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1228
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1239
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1240
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1279
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1287
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1304
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1321
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1322
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1335
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1339
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1346
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1354
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1356
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1360
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1369
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1371
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1381
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1384
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1388
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1390
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1404
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1422
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1447
# [INFO] [get_croppeddata] NoOverlapError: filling with nans for Region 1448
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/hstha_hdu.pickel
# [INFO] Running for musha_hdu...
# Cropping regions:   0%|          | 0/1455 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/musha_hdu.pickel
# [INFO] Running for muscat_hdu...
# Cropping regions:   0%|          | 0/1455 [00:00<?, ?it/s]
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/muscat_hdu.pickel

# %%
# Load all cutouts and save in one file... 

names = ['hstha_hdu', 'musha_hdu', 'muscat_hdu']
hdus_cutouts = {}

for name in tqdm(names):

    hdu_cutouts = dendro_misc.load_pickle('%s/%s.pickel' %(cutout_dir, name))
    hdus_cutouts[name] = hdu_cutouts

dendro_misc.save_pickle(hdus_cutouts, '%s/hdus_all.pickel' %cutout_dir)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/hstha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/musha_hdu.pickel
# [INFO] [load_pickle] Load /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/muscat_hdu.pickel
# [INFO] [save_pickle] Saved to /Users/abarnes/Dropbox/work/Smallprojects/galaxies/data_hstha_nebulae_catalogue/ngc1365n/cutouts/hdus_all.pickel
