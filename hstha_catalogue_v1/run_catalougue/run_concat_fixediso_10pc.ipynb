# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.table import QTable, join, vstack
import numpy as np
import os

from astropy.table import vstack

import sys
sys.path.append('./../')
import time

# %%
def get_concat(dir_endswith='catalogue', file_endswith='props_all.fits', output_dir='./', muscat_table_file=''):
    """ 
    Concatenate tables from all directories 

    Parameters
    ----------
    dir_endswith : str
        Directory name ends with this string, e.g. 'catalogue' or 'catalogue_isofix'
    filename : str
        File name ends with this string, e.g. 'props_all.fits' or 'props_all_association.fits'

    Returns
    -------
    table : astropy.table.Table
        Concatenated table
    """

    tables = []
    for root, dirs, files in os.walk(output_dir):
        if not root.endswith(dir_endswith):
            continue
        for file in files:
            if file.endswith(file_endswith):
                if 'dendro' in root:
                    continue

                filename = os.path.join(root, file)
                filemodtime = time.ctime(os.path.getmtime(filename))
                print(f"{filename} \t - {filemodtime}")
                tables += [QTable.read(os.path.join(root, file))]

    print('TOTAL NUMBER OF TABLES:', len(tables)) # Number of tables

    # Join tables
    table = vstack(tables)

    # Order by galaxy names and region IDs from MUSE
    gal_name = table['gal_name']
    table.remove_column('gal_name')
    table.add_column(gal_name, index=0)
    table.sort(['gal_name', 'region_ID'])

    # Mask out NaN values
    mask = np.isnan(np.array(table['HA6562_LUMINOSITY_HST']))
    table_masked = table[~mask]
    
    # TODO - update scripts to use v4 catalogue...  
    # REMOVE THE FOLLOWING
    #####################################
    ### Add MUSE catalogue properties ###
    # Replacing with v4 MUSE catalogue properties - for N2 and S3 TEMPS mainly...
    # Note that scripts used to make catalogue are using the v3 MUSE catalogue...

    table_muse = QTable.read(muscat_table_file)
    columns = table_muse.colnames
    for column in columns:
        table_muse.rename_column(column, column+'_MUSE')
    table_muse.rename_column('gal_name_MUSE', 'gal_name')
    table_muse.rename_column('region_ID_MUSE', 'region_ID')
    table_muse.rename_column('Lum_HA6562_CORR_MUSE', 'HA6562_LUMINOSITY_MUSE')

    table_masked = join(table_masked, table_muse, keys=['gal_name', 'region_ID'])

    for colname in table_masked.colnames:
        if '_MUSE_1' in colname:
            table_masked.remove_column(colname)
        if '_MUSE_2' in colname:
            table_masked.rename_column(colname, colname.replace('_MUSE_2', '_MUSE'))
        if 't_N2' in colname:
            table_masked.remove_column(colname)
        if 't_S3' in colname:
            table_masked.remove_column(colname)
    #####################################

    return table_masked

# %%
# Define names and filenames...

output_dir = '/Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/'
muscat_table_file = '/Users/abarnes/Library/CloudStorage/Dropbox/Data/Extragalactic/catalogues/Nebulae_catalogue_v4/Nebulae_catalogue_v4.fits'

print(output_dir)
print(muscat_table_file)
# Out:
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/
# /Users/abarnes/Library/CloudStorage/Dropbox/Data/Extragalactic/catalogues/Nebulae_catalogue_v4/Nebulae_catalogue_v4.fits

# %%
# For all galaxies - WITHOUT stellar properties...
table_WITHOUT_associations = get_concat('catalogue_fixediso_10pc', 'props_all.fits', output_dir, muscat_table_file)
table_WITHOUT_associations.write(output_dir+'/all/nebulae_catalogue_fixediso_10pc.fits', overwrite=True)
# Out:
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc3627/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:24:45 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4254/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:28:07 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1512/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:13:39 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1433/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:11:12 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc5068/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:39:17 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4321/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:34:20 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1365n/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:06:36 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4303/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:31:39 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc2835/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:20:06 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1087/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:00:33 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc7496/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:41:15 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1385/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:08:24 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ic5332/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 10:54:49 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc3351/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:22:16 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc628c/catalogue_fixediso_10pc/props_all.fits 	 - Fri May 30 13:53:33 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1672/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:18:24 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4535/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:36:15 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1300/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:03:50 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1566/catalogue_fixediso_10pc/props_all.fits 	 - Mon May 26 11:15:45 2025
# TOTAL NUMBER OF TABLES: 19

# %%
# For all galaxies - WITH stellar properties...
table_WITH_associations = get_concat('catalogue_fixediso_10pc', 'props_all_association.fits', output_dir, muscat_table_file)
table_WITH_associations.write(output_dir+'/all/nebulae_catalogue_wassociations_fixediso_10pc.fits', overwrite=True)
# Out:
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc3627/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:25:32 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4254/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:29:25 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1512/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:14:14 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1433/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:11:36 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc5068/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:39:50 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4321/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:35:07 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1365n/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:07:02 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4303/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:32:58 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc2835/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:20:39 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1087/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:01:13 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc7496/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:41:37 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1385/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:08:58 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ic5332/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 10:55:11 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc3351/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:22:48 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc628c/catalogue_fixediso_10pc/props_all_association.fits 	 - Fri May 30 13:54:01 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1672/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:19:08 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc4535/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:36:52 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1300/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:04:20 2025
# /Users/abarnes/Library/CloudStorage/Dropbox/Projects/Extragalactic/hstha_nebulae_catalogue/ngc1566/catalogue_fixediso_10pc/props_all_association.fits 	 - Mon May 26 11:16:39 2025
# TOTAL NUMBER OF TABLES: 19

# %%
table_WITH_associations
# Out:
# <QTable length=5467>
# gal_name region_ID  x_max  ...   TEM_SIII_MUSE   TEM_SIII_ERR_MUSE
#                      pix   ...         K                 K
# bytes32   float64  float64 ...      float64           float64
# -------- --------- ------- ... ----------------- -----------------
#   IC5332       7.0    50.0 ...               ———               ———
#   IC5332      17.0    67.0 ...               ———               ———
#   IC5332      26.0    83.0 ... 8531.888757728628 90.00203830193833
#   IC5332      28.0    47.0 ...               ———               ———
#   IC5332      29.0    49.0 ...               ———               ———
#   IC5332      31.0    68.0 ... 9297.349499171018 155.7139650309837
#   IC5332      33.0    43.0 ...               ———               ———
#   IC5332      55.0    70.0 ...               ———               ———
#   IC5332      57.0    59.0 ...               ———               ———
#      ...       ...     ... ...               ...               ...
#  NGC7496     612.0    41.0 ...               ———               ———
#  NGC7496     633.0    26.0 ...               ———               ———
#  NGC7496     641.0   109.0 ...               ———               ———
#  NGC7496     650.0    60.0 ...               ———               ———
#  NGC7496     679.0    77.0 ...               ———               ———
#  NGC7496     721.0    54.0 ...               ———               ———
#  NGC7496     725.0    32.0 ...               ———               ———
#  NGC7496     765.0    22.0 ...               ———               ———
#  NGC7496     776.0    31.0 ...               ———               ———

# %%
table_WITHOUT_associations
# Out:
# <QTable length=5467>
# gal_name region_ID  x_max  ...   TEM_SIII_MUSE   TEM_SIII_ERR_MUSE
#                      pix   ...         K                 K
# bytes32   float64  float64 ...      float64           float64
# -------- --------- ------- ... ----------------- -----------------
#   IC5332       7.0    50.0 ...               ———               ———
#   IC5332      17.0    67.0 ...               ———               ———
#   IC5332      26.0    83.0 ... 8531.888757728628 90.00203830193833
#   IC5332      28.0    47.0 ...               ———               ———
#   IC5332      29.0    49.0 ...               ———               ———
#   IC5332      31.0    68.0 ... 9297.349499171018 155.7139650309837
#   IC5332      33.0    43.0 ...               ———               ———
#   IC5332      55.0    70.0 ...               ———               ———
#   IC5332      57.0    59.0 ...               ———               ———
#      ...       ...     ... ...               ...               ...
#  NGC7496     612.0    41.0 ...               ———               ———
#  NGC7496     633.0    26.0 ...               ———               ———
#  NGC7496     641.0   109.0 ...               ———               ———
#  NGC7496     650.0    60.0 ...               ———               ———
#  NGC7496     679.0    77.0 ...               ———               ———
#  NGC7496     721.0    54.0 ...               ———               ———
#  NGC7496     725.0    32.0 ...               ———               ———
#  NGC7496     765.0    22.0 ...               ———               ———
#  NGC7496     776.0    31.0 ...               ———               ———
