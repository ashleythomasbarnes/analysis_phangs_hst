# %%
import warnings
warnings.filterwarnings('ignore')

from astropy.table import QTable, join, vstack
import numpy as np
import os

from astropy.table import vstack

import sys
sys.path.append('./../')
import time

# %%
def get_concat(dir_endswith='catalogue', file_endswith='props_all.fits', output_dir='./', muscat_table_file=''):
    """ 
    Concatenate tables from all directories 

    Parameters
    ----------
    dir_endswith : str
        Directory name ends with this string, e.g. 'catalogue' or 'catalogue_isofix'
    filename : str
        File name ends with this string, e.g. 'props_all.fits' or 'props_all_association.fits'

    Returns
    -------
    table : astropy.table.Table
        Concatenated table
    """

    tables = []
    for root, dirs, files in os.walk(output_dir):
        if not root.endswith(dir_endswith):
            continue
        for file in files:
            if file.endswith(file_endswith):
                if 'dendro' in root:
                    continue
                
                filename = os.path.join(root, file)
                filemodtime = time.ctime(os.path.getmtime(filename))
                print(f"{filename} \t - {filemodtime}")
                tables += [QTable.read(os.path.join(root, file))]

    print('TOTAL NUMBER OF TABLES:', len(tables)) # Number of tables

    # Join tables
    table = vstack(tables)

    # Order by galaxy names and region IDs from MUSE
    gal_name = table['gal_name']
    table.remove_column('gal_name')
    table.add_column(gal_name, index=0)
    table.sort(['gal_name', 'region_ID'])

    # Mask out NaN values
    mask = np.isnan(np.array(table['HA6562_LUMINOSITY_HST']))
    table_masked = table[~mask]
    
    # TODO - update scripts to use v4 catalogue...  
    # REMOVE THE FOLLOWING
    #####################################
    ### Add MUSE catalogue properties ###
    # Replacing with v4 MUSE catalogue properties - for N2 and S3 TEMPS mainly...
    # Note that scripts used to make catalogue are using the v3 MUSE catalogue...

    table_muse = QTable.read(muscat_table_file)
    columns = table_muse.colnames
    for column in columns:
        table_muse.rename_column(column, column+'_MUSE')
    table_muse.rename_column('gal_name_MUSE', 'gal_name')
    table_muse.rename_column('region_ID_MUSE', 'region_ID')
    table_muse.rename_column('Lum_HA6562_CORR_MUSE', 'HA6562_LUMINOSITY_MUSE')

    table_masked = join(table_masked, table_muse, keys=['gal_name', 'region_ID'])

    for colname in table_masked.colnames:
        if '_MUSE_1' in colname:
            table_masked.remove_column(colname)
        if '_MUSE_2' in colname:
            table_masked.rename_column(colname, colname.replace('_MUSE_2', '_MUSE'))
        if 't_N2' in colname:
            table_masked.remove_column(colname)
        if 't_S3' in colname:
            table_masked.remove_column(colname)
    #####################################

    return table_masked

# %%
# Define names and filenames...
root_dir = '/Users/abarnes/Dropbox/work/Smallprojects/galaxies/'

output_dir = '%s/data_hstha_nebulae_catalogue/' %(root_dir)
muscat_table_file = '%s/data_misc/Nebulae_catalogue_v4/Nebulae_catalogue_v4.fits' %root_dir # v4 catalogue

print(output_dir)
print(muscat_table_file)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_misc/Nebulae_catalogue_v4/Nebulae_catalogue_v4.fits

# %%
# For all galaxies - WITHOUT stellar properties...
table_WITHOUT_associations = get_concat('catalogue_fixediso', 'props_all.fits', output_dir, muscat_table_file)
table_WITHOUT_associations.write(output_dir+'/all/nebulae_catalogue_fixediso.fits', overwrite=True)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc3627/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:26:42 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4254/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:34:13 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1512/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:09:52 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1433/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:08:16 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc5068/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 22:01:58 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4321/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:52:17 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1365n/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:02:40 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4303/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:44:48 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1087/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 20:55:35 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc7496/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 22:05:00 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1385/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:05:08 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc2835s/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:20:33 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ic5332/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 20:46:55 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc3351/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:22:50 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc628c/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 20:51:58 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1672/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:17:48 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4535/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:56:49 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1300/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 20:59:26 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1566/catalogue_fixediso/props_all.fits 	 - Tue Jan 14 21:13:38 2025
# TOTAL NUMBER OF TABLES: 19

# %%
# For all galaxies - WITH stellar properties...
table_WITH_associations = get_concat('catalogue_fixediso', 'props_all_association.fits', output_dir, muscat_table_file)
table_WITH_associations.write(output_dir+'/all/nebulae_catalogue_wassociations_fixediso.fits', overwrite=True)
# Out:
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc3627/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:28:44 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4254/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:39:44 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1512/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:10:14 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1433/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:08:53 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc5068/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 22:03:48 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4321/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:54:15 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1365n/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:03:25 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4303/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:49:11 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1087/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 20:57:18 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc7496/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 22:05:32 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1385/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:06:07 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc2835s/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:21:01 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ic5332/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 20:47:26 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc3351/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:23:40 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc628c/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 20:53:52 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1672/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:19:09 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc4535/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:58:25 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1300/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:00:24 2025
# /Users/abarnes/Dropbox/work/Smallprojects/galaxies//data_hstha_nebulae_catalogue/ngc1566/catalogue_fixediso/props_all_association.fits 	 - Tue Jan 14 21:15:10 2025
# TOTAL NUMBER OF TABLES: 19

# %%
table_WITH_associations
# Out:
# <QTable length=7697>
# gal_name region_ID  x_max  ...   TEM_SIII_MUSE   TEM_SIII_ERR_MUSE
#                      pix   ...         K                 K
# bytes32   float64  float64 ...      float64           float64
# -------- --------- ------- ... ----------------- -----------------
#   IC5332       3.0    43.0 ...               ———               ———
#   IC5332       7.0    50.0 ...               ———               ———
#   IC5332      10.0    42.0 ...               ———               ———
#   IC5332      11.0    29.0 ...               ———               ———
#   IC5332      15.0    34.0 ...               ———               ———
#   IC5332      17.0    67.0 ...               ———               ———
#   IC5332      18.0    36.0 ...               ———               ———
#   IC5332      19.0    36.0 ...               ———               ———
#   IC5332      26.0    82.0 ... 8531.888757728628 90.00203830193833
#      ...       ...     ... ...               ...               ...
#  NGC7496     707.0    30.0 ...               ———               ———
#  NGC7496     721.0    54.0 ...               ———               ———
#  NGC7496     725.0    32.0 ...               ———               ———
#  NGC7496     726.0    33.0 ...               ———               ———
#  NGC7496     735.0    27.0 ...               ———               ———
#  NGC7496     743.0    32.0 ...               ———               ———
#  NGC7496     744.0    28.0 ...               ———               ———
#  NGC7496     765.0    25.0 ...               ———               ———
#  NGC7496     773.0    29.0 ...               ———               ———
#  NGC7496     776.0    31.0 ...               ———               ———

# %%
table_WITHOUT_associations
# Out:
# <QTable length=7697>
# gal_name region_ID  x_max  ...   TEM_SIII_MUSE   TEM_SIII_ERR_MUSE
#                      pix   ...         K                 K
# bytes32   float64  float64 ...      float64           float64
# -------- --------- ------- ... ----------------- -----------------
#   IC5332       3.0    43.0 ...               ———               ———
#   IC5332       7.0    50.0 ...               ———               ———
#   IC5332      10.0    42.0 ...               ———               ———
#   IC5332      11.0    29.0 ...               ———               ———
#   IC5332      15.0    34.0 ...               ———               ———
#   IC5332      17.0    67.0 ...               ———               ———
#   IC5332      18.0    36.0 ...               ———               ———
#   IC5332      19.0    36.0 ...               ———               ———
#   IC5332      26.0    82.0 ... 8531.888757728628 90.00203830193833
#      ...       ...     ... ...               ...               ...
#  NGC7496     707.0    30.0 ...               ———               ———
#  NGC7496     721.0    54.0 ...               ———               ———
#  NGC7496     725.0    32.0 ...               ———               ———
#  NGC7496     726.0    33.0 ...               ———               ———
#  NGC7496     735.0    27.0 ...               ———               ———
#  NGC7496     743.0    32.0 ...               ———               ———
#  NGC7496     744.0    28.0 ...               ———               ———
#  NGC7496     765.0    25.0 ...               ———               ———
#  NGC7496     773.0    29.0 ...               ———               ———
#  NGC7496     776.0    31.0 ...               ———               ———
